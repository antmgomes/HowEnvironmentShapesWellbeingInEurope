# %% [markdown]
# Imports

# %%
import pandas as pd

import requests
from bs4 import BeautifulSoup

# %%
# Happiness Index - Wikipedia (Data Scraping)
url = "https://en.wikipedia.org/wiki/World_Happiness_Report#cite_note-22"

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:145.0) Gecko/20100101 Firefox/145.0"}

response = requests.get(url, headers = headers)
response
# Out:
# <Response [200]>

# %%
#Renaming columns
df_happiness = df_happiness.rename(columns = {'Country':'country', 'Happiness Score':'happiness_score'})

#Dropping unnecessary columns
df_happiness = df_happiness.drop(['2011', '2012', '2013', '2014'], axis=1)

#Removing unnecessary rows
df_happiness = df_happiness[df_happiness['country'] != 'Portugal']
df_happiness = df_happiness[df_happiness['country'] != 'Madeira']
df_happiness = df_happiness[df_happiness['country'] != 'Açores']

#Resetting index
df_happiness = df_happiness.reset_index(drop=True)

# %%
import pandas as pd

df_health = pd.read_csv(r"C:\Users\NocTo\OneDrive\Ambiente de Trabalho\PP1\PersonalProject_1\Data\Share of People with Good or Very Good Perceived Health - Eurostat.csv")
df_health
# Out:
#             country  2015  2016  2017  2018  2019  2020  2021  2022  2023  \
# 0           Belgium  74.6  73.9  74.5  74.9  74.1  75.6  76.5  75.4  75.5
# 1          Bulgaria  65.6  65.8  66.7  66.5  67.2  66.7  67.6  68.2  65.1
# 2           Czechia  61.3  60.4  61.9  62.1  62.0  63.4  67.8  68.0  66.5
# 3           Denmark  71.6  71.3  71.3  71.2  69.7  71.3  67.0  63.0  64.5
# 4           Germany  64.6  65.2  65.5  65.5  65.5  63.9  63.0  64.2  65.6
# 5           Estonia  51.5  52.9  52.5  51.8  56.6  58.4  58.3  57.8  56.3
# 6           Ireland  82.6  82.9  83.3  84.1  84.3  84.5  81.7  80.8  79.5
# 7            Greece  74.1  74.0  74.1  76.4  79.3  78.6  78.3  77.2  78.3
# 8             Spain  72.6  72.5  74.2  73.7  75.3  73.0  71.2  70.1  70.2
# 9            France  67.9  66.4  67.4  67.7  66.7  68.4  67.9  65.2  64.9
# 10          Croatia  58.2  59.2  60.9  60.7  60.5  63.7  62.8  63.2  65.0
# 11            Italy  65.8  70.9  77.0  73.3  72.9   NaN  73.6  72.9  73.9
# ...

# %%
#Turn it from a wide to a long format
df_health = pd.melt(df_health, id_vars=['country'], var_name='year', value_name='good_health_percentage')

# %%
df_health
# Out:
#              country  year  good_health_percentage
# 0            Belgium  2015                    74.6
# 1           Bulgaria  2015                    65.6
# 2            Czechia  2015                    61.3
# 3            Denmark  2015                    71.6
# 4            Germany  2015                    64.6
# ..               ...   ...                     ...
# 365  North Macedonia  2024                     NaN
# 366          Albania  2024                     NaN
# 367           Serbia  2024                    64.2
# 368          Türkiye  2024                    63.8
# 369          Kosovo*  2024                     NaN
#
# [370 rows x 3 columns]
